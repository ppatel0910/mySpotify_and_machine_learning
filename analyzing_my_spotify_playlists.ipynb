# %% [markdown]
# # Analyzing my Spotify Playlists 🎶

# %% [markdown]
# ## General Process
# ##### I connected to the Spotify web API using the instructions provided from the link above, and was granted a client ID, and a client secret key. With these credentials, I requested an access token and was successfully able to make calls to the Spotify web API. I then made calls to the Spotify API using the imported Python library, Spotipy, to retrieve data such as my playlists, tracks within the playlists, etc. I then compiled the extracted data into a pandas dataframe to create graphs and analyzed my playlists regarding metrics such as category and time of day.

# %% [markdown]
# ### Connect to the Spotify API

# %%
# Import all libraries used throughout the notebook

import os 
from dotenv import load_dotenv
import spotipy 
from spotipy.oauth2 import SpotifyOAuth
from requests import post
import base64
import json
from IPython.display import Image
import pandas as pd
import matplotlib.pyplot as plot

# %%
# Construct variables to hold access credentials needed in order to connect 
# with the SpotifY API

# Create a local .env file, to create and hold 'my client_id' and 'client_secret_id' 
# variables
load_dotenv()

my_id = os.getenv("my_id")
my_secret_key = os.getenv("my_secret_id")
redirect_uri = "http://localhost:3000"

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager = SpotifyOAuth(client_id = my_id,
                                               client_secret = my_secret_key,
                                               redirect_uri = redirect_uri,
                                               scope = "playlist-read-private user-read-recently-played"))

# %% [markdown]
# #### Retrieving an Access Token

# %%
# Retrieving a token
def get_token():
    authorization_string = my_id + ":" + my_secret_key
    authorization_bytes = authorization_string.encode("utf-8")
    authorization_base64 = str(base64.b64encode(authorization_bytes), "utf-8")
    
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + authorization_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = post(url, headers = headers, data = data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token

token = get_token()
#print(token)

def get_authorization_header(token):
    return{"Authorization": "Bearer " + token}

# %% [markdown]
# #### After running the above cell, a seperate webpage opens to confirm allowing access to my personal Spotify account. After clicking the 'Agree' button, we have successfully connected to my Spotify account, the webpage is displayed in the screenshot below. We can now begin to analyze my Spotify account! 🎉

# %%
Image(url = "https://github.com/ppatel0910/mySpotify_and_machine_learning/blob/main/images/spotify_token_redirect.png",
     height = 300)
# Out:
# <img src="https://github.com/ppatel0910/mySpotify_and_machine_learning/blob/main/images/spotify_token_redirect.png" height="300"/>

# %% [markdown]
# ### Extracting my Music

# %%
# Retrieve the album ID from all my current playlists, with the album IDs I can
# analyze the playlists of my choosing 

playlists = sp.current_user_playlists(limit = 50, offset=0)
for playlist in playlists['items']:
    print("Playlist:", playlist['name'])
    print("Playlist ID:", playlist['id'])
    print()
# Out:
# Playlist: 🜷 · L U C
# Playlist ID: 08PhoI8GTrYY5RLCw7FTGs
#
# Playlist: Beautiful Things
# Playlist ID: 4jBNp0HyRsdaW2mreEEBmy
#
# Playlist: gymcore
# Playlist ID: 37i9dQZF1DX5n5gZBZb0AT
#
# Playlist: Your Top Songs 2023
# Playlist ID: 37i9dQZF1Fa1IIVtEpGUcU
#
# Playlist: phonk
# Playlist ID: 37i9dQZF1DWWY64wDtewQt
#
# Playlist: ☠️
# Playlist ID: 36sWCIuz8qsiR24qNBMGKt
#
# Playlist: yea
# Playlist ID: 3Z4JXpMvdFtSfwlt5UOVeM
#
# Playlist: ♨️
# Playlist ID: 4SFa1odhkTaQen705xiObH
#
# Playlist: 💰💰💰💰💰💰💰💰💰💰💰💰💰
# Playlist ID: 4xrHb5Wju7CKwgR06dxKQn
#
# Playlist: ✨
# Playlist ID: 52SUls5Z9UfIwwUuQdzZfx
#
# Playlist: Your Top Songs 2022
# Playlist ID: 37i9dQZF1F0sijgNaJdgit
#
# Playlist: Your Top Songs 2021
# Playlist ID: 37i9dQZF1EUMDoJuT8yJsl
#
# Playlist: Your Top Songs 2020
# Playlist ID: 37i9dQZF1EM8XokzgDW8MX
#
# Playlist: random
# Playlist ID: 0pEkOWP7xIHk0RkucmGQ5I
#
# Playlist: NEW SPANISH TRAP
# Playlist ID: 0MCNQTgcmJOdA5RaYQZbjT
#
# Playlist: Spanish Trap
# Playlist ID: 4GkuLJQ4zte0yYF0msUNtw
#
# Playlist: Eklavya + Priya
# Playlist ID: 37i9dQZF1EJtpC3JTdWYfV
#
# Playlist: hot girl
# Playlist ID: 5xYfCE46cAGAFdZimcs9yC
#
# Playlist: 🏏
# Playlist ID: 7dwO2ZUlYDNWhgow20wMnO
#
# Playlist: Hip bolly
# Playlist ID: 1gaWVbmoLFU0AnLBKNcxcc
#
# Playlist: sadboi hours
# Playlist ID: 1GtkxWoPEOnNOzcf1GFae5
#
# Playlist: One Last Thing....
# Playlist ID: 2WQLTqAIE7UQ3H4Vxx44yE
#
# Playlist: 👽
# Playlist ID: 5R5B9HPAtIo2k1qQZ97T1Q
#
# Playlist: 💯
# Playlist ID: 0yPNZjVb7wp6b0dpOUuNby
#
# Playlist: Release Radar
# Playlist ID: 37i9dQZEVXbbRTavqp6j2m
#
# Playlist:
# Playlist ID: 54zKHXQdjJYQc5srgpjOjm
#
# Playlist: 💪🏽
# Playlist ID: 2nhWIzWoNWOkJx02i9vqIa
#
# Playlist: 😌
# Playlist ID: 279x6EFu5xYeJW3pvaDp3W
#
# Playlist: 🙇🏼‍♀️
# Playlist ID: 5XKNLddyL1zuK2oDMzJ6cM
#
# Playlist: 🦚
# Playlist ID: 44tglVDSpkZ1jUHRQP5mh8
#
# Playlist: Happy Hits!
# Playlist ID: 37i9dQZF1DXdPec7aLTmlC
#
# Playlist: Feelin' Myself
# Playlist ID: 37i9dQZF1DX6GwdWRQMQpq
#
# Playlist: Boss Ass bitch $$$$
# Playlist ID: 0nQ0jU9msWXjHu121CFL4P
#
# Playlist: 💃🏽
# Playlist ID: 3HKx2Xx0fn36b0DJbTQ8il
#
# Playlist: Locked In
# Playlist ID: 37i9dQZF1DWTl4y3vgJOXW
#
# Playlist: Gold Edition
# Playlist ID: 37i9dQZF1DWXnexX7CktaI
#
# Playlist: 🥰
# Playlist ID: 1hoN2uRdSpWPT8dBAgKhdV
#
# Playlist: 2k18-19
# Playlist ID: 25My4V69yNZG43slhcLccD
#
# Playlist: thug life
# Playlist ID: 17BCQRLJgoC6Tps8N3QIIX
#
# Playlist: My Shazam Tracks
# Playlist ID: 7vEW37HpfVBlQo33iZy40b
#
# Playlist: Your Top Songs 2016
# Playlist ID: 37i9dQZF1CyM4aoWzGuoJ5
#
# Playlist: Feeling Accomplished
# Playlist ID: 37i9dQZF1DWTDafB3skWPN
#
# Playlist: Hype
# Playlist ID: 37i9dQZF1DX4eRPd9frC1m
#
# Playlist: ooh
# Playlist ID: 4Eb48BrseYB5NRZabc6SZC
#
# Playlist: Life Sucks
# Playlist ID: 37i9dQZF1DX3YSRoSdA634
#
# Playlist: Liked from Radio
# Playlist ID: 3v6ycwFEJSMECHK2OAO8Px

# %%
# I can recognize most of my playlists from the results, but I cannot tell what 
# is in the playlist "Liked from Radio". List all the songs in the playlist to 
# decide if it should be included in my dataset.  


# Define the function 'get_all_tracks_from_playlist' to list all of the songs 
# in a playlist

def get_all_tracks_from_playlist(playlist_id):
    tracks_response = sp.playlist_tracks(playlist_id)
    tracks = tracks_response["items"]
    while tracks_response["next"]:
        tracks_response = sp.next(tracks_response)
        tracks.extend(tracks_response["items"])

    return tracks

playlist_ID = "3v6ycwFEJSMECHK2OAO8Px"
tracks = get_all_tracks_from_playlist(playlist_ID)

print("Number of tracks in the playlist:", len(tracks))

for track in tracks:
    print(track["track"]["name"])
# Out:
# Number of tracks in the playlist: 103
# Te Lo Meto Yo (feat. Bad Bunny, Lary Over, Farruko, Arcangel & Tempo)
# Drinks On Us
# No Option
# I Told You/ Another One
# goosebumps
# In For It
# F*ck Up Some Commas
# Controlla
# Friends With Benefits
# Too Good
# Controlla
# through the late night
# Friends With Benefits
# Pull Up (feat. Lil Uzi Vert)
# Don't
# pick up the phone
# Sorry Not Sorry
# Acquainted
# Far Alone (feat. E-40 & Jay Ant)
# A-Team
# Tumblr Girls (feat. Christoph Andersson)
# G.O.M.D.
# Don't Let Me Go (feat. SAYGRACE)
# Jumpman
# One Dance
# Sober
# 4u
# Verbatim
# Idfc
# What If (feat. Gizzle)
# untitled 07 | 2014 - 2016
# Low Life (feat. The Weeknd)
# One Of Them (feat. Big Sean)
# Change Locations
# Stuck On U
# Traphouse
# A-Team
# In For It
# One Day
# Remembrance Day
# Change Locations
# Stuck On U
# Acting Like
# LA Confidential
# Exchange
# Pop Style
# One Day
# Wicked
# Come and See Me (feat. Drake)
# Back Up (feat. Big Sean)
# 502 Come Up
# Handsome And Wealthy
# N.I.N.A
# By Chance
# Comfortable
# Hotline Bling
# Antidote
# Planez
# Traphouse
# Wavy (feat. Joe Moses)
# Come and See Me (feat. Drake)
# Pop Style
# Say It
# I'm Guilty (feat. Mr. Boogiie & Majestic Drama)
# B.L.O.W.
# Jersey
# Im On You (Feat. Tory Lanez)
# Thought It Was a Drought
# Me, Myself & I
# It's Not Over
# Remember the Name (feat. Styles of Beyond)
# 3 a.m.
# ...To Be Loved
# Breathe Into Me
# Goin' Down
# Ladies And Gentlemen
# Breath
# Good Times
# The Diary of Jane
# Apologize
# Edge Of The Earth
# Follow
# Stay In Shadow
# Away
# Drunk
# Autumn Leaves - Deluxe Edition
# River - Acoustic Version
# The District Sleeps Alone Tonight
# All We Are
# Never Fade
# Radiation
# Paradise - Acoustic
# Encore/Curtains Down
# Numb / Encore
# Lose Yourself - Soundtrack Version
# ...To Be Loved
# Gold Rush - Deluxe Edition
# New Scene (feat. Ofelia)
# Hey Now - Single Mix
# Trumpsta (Djuro remix) [feat. Treyy G]
# Cinderella (She Said Her Name) - Radio Edit
# Still Sane
# Breezeblocks

# %%
# Using tke playlist ID's extracted above, I created a list of dictionaries to
# hold only the playlists I wanted to include in my dataset (the playlist 
# examined above was included in this dataset). 

playlist_ids = [{"album_id" : "37i9dQZF1DX5n5gZBZb0AT", "category" : "phonk", "year" : "2023"},
               {"album_id" : "37i9dQZF1Fa1IIVtEpGUcU", "category" : "spotifyWrapped2023", "year" : "2023"},
               {"album_id" : "36sWCIuz8qsiR24qNBMGKt", "category" : "phonk", "year" : "2023"},
               {"album_id" : "3Z4JXpMvdFtSfwlt5UOVeM", "category" : "friend_playlist", "year" : "2023"},
               {"album_id" : "4SFa1odhkTaQen705xiObH", "category" : "friend_playlist", "year" : "2023"},
               {"album_id" : "4xrHb5Wju7CKwgR06dxKQn", "category" : "friend_playlist", "year" : "2023"},
               {"album_id" : "52SUls5Z9UfIwwUuQdzZfx", "category" : "pop_hip_hop", "year" : "2022"},
               {"album_id" : "37i9dQZF1F0sijgNaJdgit", "category" : "spotifyWrapped2022", "year" : "2022"},
               {"album_id" : "37i9dQZF1EUMDoJuT8yJsl", "category" : "spotifyWrapped2021", "year" : "2021"},
               {"album_id" : "37i9dQZF1EM8XokzgDW8MX", "category" : "spotifyWrapped2020", "year" : "2020"},
               {"album_id" : "0pEkOWP7xIHk0RkucmGQ5I", "category" : "random", "year" : "2021"},
               {"album_id" : "0MCNQTgcmJOdA5RaYQZbjT", "category" : "spanish", "year" : "2021"},
               {"album_id" : "4GkuLJQ4zte0yYF0msUNtw", "category" : "spanish", "year" : "2021"},
               {"album_id" : "37i9dQZF1EJtpC3JTdWYfV", "category" : "friend_blend", "year" : "2021"},
               {"album_id" : "5xYfCE46cAGAFdZimcs9yC", "category" : "pop_hip_hop", "year" : "2021"},
               {"album_id" : "7dwO2ZUlYDNWhgow20wMnO", "category" : "bollywood", "year" : "2022"},
               {"album_id" : "1gaWVbmoLFU0AnLBKNcxcc", "category" : "friend_playlist", "year" : "2022"},
               {"album_id" : "1GtkxWoPEOnNOzcf1GFae5", "category" : "sad", "year" : "2020"},
               {"album_id" : "5R5B9HPAtIo2k1qQZ97T1Q", "category" : "alt", "year" : "2021"},
               {"album_id" : "5R5B9HPAtIo2k1qQZ97T1Q", "category" : "alt", "year" : "2021"},
               {"album_id" : "0yPNZjVb7wp6b0dpOUuNby", "category" : "hip_hop", "year" : "2020"},
               {"album_id" : "2nhWIzWoNWOkJx02i9vqIa", "category" : "pop_hip-hop", "year" : "2020"},
               {"album_id" : "279x6EFu5xYeJW3pvaDp3W", "category" : "pop_alt", "year" : "2020"},
               {"album_id" : "5XKNLddyL1zuK2oDMzJ6cM", "category" : "pop", "year" : "2020"},
               {"album_id" : "44tglVDSpkZ1jUHRQP5mh8", "category" : "hip_hop", "year" : "2020"},
               {"album_id" : "0nQ0jU9msWXjHu121CFL4P", "category" : "pop_hip_hop", "year" : "2020"},
               {"album_id" : "37i9dQZF1DXdPec7aLTmlC", "category" : "pop", "year" : "2020"},
               {"album_id" : "37i9dQZF1DWXnexX7CktaI", "category" : "hip_hop_r&b", "year" : "2020"},
               {"album_id" : "1hoN2uRdSpWPT8dBAgKhdV", "category" : "love", "year" : "2021"},
               {"album_id" : "25My4V69yNZG43slhcLccD", "category" : "friend_playlist", "year" : "2019"},
               {"album_id" : "17BCQRLJgoC6Tps8N3QIIX", "category" : "hip_hop", "year" : "2019"},
               {"album_id" : "7vEW37HpfVBlQo33iZy40b", "category" : "random", "year" : "2019"},
               {"album_id" : "37i9dQZF1CyM4aoWzGuoJ5", "category" : "spotifyWrapped2016", "year" : "2016"},
               {"album_id" : "37i9dQZF1DWTDafB3skWPN", "category" : "hip_hop", "year" : "2017"},
               {"album_id" : "37i9dQZF1DX4eRPd9frC1m", "category" : "edm", "year" : "2017"},
               {"album_id" : "4Eb48BrseYB5NRZabc6SZC", "category" : "hip_hop", "year" : "2016"},
               {"album_id" : "37i9dQZF1DX3YSRoSdA634", "category" : "sad", "year" : "2020"},
               {"album_id" : "3v6ycwFEJSMECHK2OAO8Px", "category" : "pop_hip_hop", "year" : "2016"},
               {"album_id" : "4jBNp0HyRsdaW2mreEEBmy", "category" : "pop_hip_hop", "year" : "2024"}]


# Create a pandas datafame from 'playlists_id', and review the dataframe

df = pd.DataFrame(playlist_ids, columns = ["album_id", "category", "year"])
df["year"] = pd.to_datetime(df["year"]).dt.strftime('%Y')
df.title = "Priya's Playlists"
df
# Out:
#                   album_id            category  year
# 0   37i9dQZF1DX5n5gZBZb0AT               phonk  2023
# 1   37i9dQZF1Fa1IIVtEpGUcU  spotifyWrapped2023  2023
# 2   36sWCIuz8qsiR24qNBMGKt               phonk  2023
# 3   3Z4JXpMvdFtSfwlt5UOVeM     friend_playlist  2023
# 4   4SFa1odhkTaQen705xiObH     friend_playlist  2023
# 5   4xrHb5Wju7CKwgR06dxKQn     friend_playlist  2023
# 6   52SUls5Z9UfIwwUuQdzZfx         pop_hip_hop  2022
# 7   37i9dQZF1F0sijgNaJdgit  spotifyWrapped2022  2022
# 8   37i9dQZF1EUMDoJuT8yJsl  spotifyWrapped2021  2021
# 9   37i9dQZF1EM8XokzgDW8MX  spotifyWrapped2020  2020
# 10  0pEkOWP7xIHk0RkucmGQ5I              random  2021
# 11  0MCNQTgcmJOdA5RaYQZbjT             spanish  2021
# 12  4GkuLJQ4zte0yYF0msUNtw             spanish  2021
# 13  37i9dQZF1EJtpC3JTdWYfV        friend_blend  2021
# 14  5xYfCE46cAGAFdZimcs9yC         pop_hip_hop  2021
# 15  7dwO2ZUlYDNWhgow20wMnO           bollywood  2022
# 16  1gaWVbmoLFU0AnLBKNcxcc     friend_playlist  2022
# 17  1GtkxWoPEOnNOzcf1GFae5                 sad  2020
# 18  5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 19  5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 20  0yPNZjVb7wp6b0dpOUuNby             hip_hop  2020
# 21  2nhWIzWoNWOkJx02i9vqIa         pop_hip-hop  2020
# 22  279x6EFu5xYeJW3pvaDp3W             pop_alt  2020
# 23  5XKNLddyL1zuK2oDMzJ6cM                 pop  2020
# 24  44tglVDSpkZ1jUHRQP5mh8             hip_hop  2020
# 25  0nQ0jU9msWXjHu121CFL4P         pop_hip_hop  2020
# 26  37i9dQZF1DXdPec7aLTmlC                 pop  2020
# 27  37i9dQZF1DWXnexX7CktaI         hip_hop_r&b  2020
# 28  1hoN2uRdSpWPT8dBAgKhdV                love  2021
# 29  25My4V69yNZG43slhcLccD     friend_playlist  2019
# 30  17BCQRLJgoC6Tps8N3QIIX             hip_hop  2019
# 31  7vEW37HpfVBlQo33iZy40b              random  2019
# 32  37i9dQZF1CyM4aoWzGuoJ5  spotifyWrapped2016  2016
# 33  37i9dQZF1DWTDafB3skWPN             hip_hop  2017
# 34  37i9dQZF1DX4eRPd9frC1m                 edm  2017
# 35  4Eb48BrseYB5NRZabc6SZC             hip_hop  2016
# 36  37i9dQZF1DX3YSRoSdA634                 sad  2020
# 37  3v6ycwFEJSMECHK2OAO8Px         pop_hip_hop  2016
# 38  4jBNp0HyRsdaW2mreEEBmy         pop_hip_hop  2024

# %% [markdown]
# ### Create a new dataframe 'playlists_df' which sorts the dataframe by category. Using 'playlists_df' we will create a bar graph to show the quantity of playlists in each category.

# %%
# Organize the dataframe based on the 'category' column, and reset the index
# to make it easier to reference data later

playlists_df = df.sort_values(by = "category")
playlists_df = playlists_df.reset_index(drop = True)
playlists_df
# Out:
#                   album_id            category  year
# 0   5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 1   5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 2   7dwO2ZUlYDNWhgow20wMnO           bollywood  2022
# 3   37i9dQZF1DX4eRPd9frC1m                 edm  2017
# 4   37i9dQZF1EJtpC3JTdWYfV        friend_blend  2021
# 5   25My4V69yNZG43slhcLccD     friend_playlist  2019
# 6   4SFa1odhkTaQen705xiObH     friend_playlist  2023
# 7   3Z4JXpMvdFtSfwlt5UOVeM     friend_playlist  2023
# 8   4xrHb5Wju7CKwgR06dxKQn     friend_playlist  2023
# 9   1gaWVbmoLFU0AnLBKNcxcc     friend_playlist  2022
# 10  37i9dQZF1DWTDafB3skWPN             hip_hop  2017
# 11  17BCQRLJgoC6Tps8N3QIIX             hip_hop  2019
# 12  44tglVDSpkZ1jUHRQP5mh8             hip_hop  2020
# 13  0yPNZjVb7wp6b0dpOUuNby             hip_hop  2020
# 14  4Eb48BrseYB5NRZabc6SZC             hip_hop  2016
# 15  37i9dQZF1DWXnexX7CktaI         hip_hop_r&b  2020
# 16  1hoN2uRdSpWPT8dBAgKhdV                love  2021
# 17  37i9dQZF1DX5n5gZBZb0AT               phonk  2023
# 18  36sWCIuz8qsiR24qNBMGKt               phonk  2023
# 19  5XKNLddyL1zuK2oDMzJ6cM                 pop  2020
# 20  37i9dQZF1DXdPec7aLTmlC                 pop  2020
# 21  279x6EFu5xYeJW3pvaDp3W             pop_alt  2020
# 22  2nhWIzWoNWOkJx02i9vqIa         pop_hip-hop  2020
# 23  5xYfCE46cAGAFdZimcs9yC         pop_hip_hop  2021
# 24  52SUls5Z9UfIwwUuQdzZfx         pop_hip_hop  2022
# 25  4jBNp0HyRsdaW2mreEEBmy         pop_hip_hop  2024
# 26  3v6ycwFEJSMECHK2OAO8Px         pop_hip_hop  2016
# 27  0nQ0jU9msWXjHu121CFL4P         pop_hip_hop  2020
# 28  0pEkOWP7xIHk0RkucmGQ5I              random  2021
# 29  7vEW37HpfVBlQo33iZy40b              random  2019
# 30  1GtkxWoPEOnNOzcf1GFae5                 sad  2020
# 31  37i9dQZF1DX3YSRoSdA634                 sad  2020
# 32  0MCNQTgcmJOdA5RaYQZbjT             spanish  2021
# 33  4GkuLJQ4zte0yYF0msUNtw             spanish  2021
# 34  37i9dQZF1CyM4aoWzGuoJ5  spotifyWrapped2016  2016
# 35  37i9dQZF1EM8XokzgDW8MX  spotifyWrapped2020  2020
# 36  37i9dQZF1EUMDoJuT8yJsl  spotifyWrapped2021  2021
# 37  37i9dQZF1F0sijgNaJdgit  spotifyWrapped2022  2022
# 38  37i9dQZF1Fa1IIVtEpGUcU  spotifyWrapped2023  2023

# %%
# Determine the number of playlists in each category, and plot the results
# using the matplotlib Python library

category_count = playlists_df["category"].value_counts()
category_count.plot(kind = "bar",
                    title = "Number of Playlists in Each Category",
                   xlabel = "Playlist Category",
                   ylabel = "Quantity")
# Out:
# <Axes: title={'center': 'Number of Playlists in Each Category'}, xlabel='Playlist Category', ylabel='Quantity'>

# %% [markdown]
# ##### My top categories for my playlists are hip-hop and ironically, my friends music. These categories were personally assigned by me, and I chose to categorize the playlists this way because it will help me analyze groups of playlists catered to my specific needs. For example, I will construct an additional dataframe containing all of my Spotify Wrapped playlists, and a dataframe for hip-hop playlists, one for phonk playlists, etc.

# %% [markdown]
# ### Create a new dataframe 'by_year_df' which sorts the dataframe by year. Using 'by_year_df' we will create a bar graph to show the quantity of playlists used during each year.

# %%
# Organize the dataframe based on the 'year' column, and reset the index
# to make it easier to reference data later

by_year_df = df.sort_values(by = "year", ascending = True)
by_year_df = by_year_df.reset_index(drop = True)
by_year_df
# Out:
#                   album_id            category  year
# 0   3v6ycwFEJSMECHK2OAO8Px         pop_hip_hop  2016
# 1   4Eb48BrseYB5NRZabc6SZC             hip_hop  2016
# 2   37i9dQZF1CyM4aoWzGuoJ5  spotifyWrapped2016  2016
# 3   37i9dQZF1DX4eRPd9frC1m                 edm  2017
# 4   37i9dQZF1DWTDafB3skWPN             hip_hop  2017
# 5   17BCQRLJgoC6Tps8N3QIIX             hip_hop  2019
# 6   7vEW37HpfVBlQo33iZy40b              random  2019
# 7   25My4V69yNZG43slhcLccD     friend_playlist  2019
# 8   37i9dQZF1DWXnexX7CktaI         hip_hop_r&b  2020
# 9   0yPNZjVb7wp6b0dpOUuNby             hip_hop  2020
# 10  37i9dQZF1DXdPec7aLTmlC                 pop  2020
# 11  0nQ0jU9msWXjHu121CFL4P         pop_hip_hop  2020
# 12  44tglVDSpkZ1jUHRQP5mh8             hip_hop  2020
# 13  5XKNLddyL1zuK2oDMzJ6cM                 pop  2020
# 14  279x6EFu5xYeJW3pvaDp3W             pop_alt  2020
# 15  37i9dQZF1DX3YSRoSdA634                 sad  2020
# 16  2nhWIzWoNWOkJx02i9vqIa         pop_hip-hop  2020
# 17  1GtkxWoPEOnNOzcf1GFae5                 sad  2020
# 18  37i9dQZF1EM8XokzgDW8MX  spotifyWrapped2020  2020
# 19  1hoN2uRdSpWPT8dBAgKhdV                love  2021
# 20  5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 21  5xYfCE46cAGAFdZimcs9yC         pop_hip_hop  2021
# 22  37i9dQZF1EJtpC3JTdWYfV        friend_blend  2021
# 23  4GkuLJQ4zte0yYF0msUNtw             spanish  2021
# 24  0MCNQTgcmJOdA5RaYQZbjT             spanish  2021
# 25  0pEkOWP7xIHk0RkucmGQ5I              random  2021
# 26  37i9dQZF1EUMDoJuT8yJsl  spotifyWrapped2021  2021
# 27  5R5B9HPAtIo2k1qQZ97T1Q                 alt  2021
# 28  1gaWVbmoLFU0AnLBKNcxcc     friend_playlist  2022
# 29  37i9dQZF1F0sijgNaJdgit  spotifyWrapped2022  2022
# 30  52SUls5Z9UfIwwUuQdzZfx         pop_hip_hop  2022
# 31  7dwO2ZUlYDNWhgow20wMnO           bollywood  2022
# 32  37i9dQZF1DX5n5gZBZb0AT               phonk  2023
# 33  4SFa1odhkTaQen705xiObH     friend_playlist  2023
# 34  3Z4JXpMvdFtSfwlt5UOVeM     friend_playlist  2023
# 35  36sWCIuz8qsiR24qNBMGKt               phonk  2023
# 36  37i9dQZF1Fa1IIVtEpGUcU  spotifyWrapped2023  2023
# 37  4xrHb5Wju7CKwgR06dxKQn     friend_playlist  2023
# 38  4jBNp0HyRsdaW2mreEEBmy         pop_hip_hop  2024

# %%
# Determine the number of playlists in each year, and plot the results
# using the matplotlib Python library

year_count = by_year_df["year"].value_counts()
year_count.plot(kind = "bar",
                    title = "Number of Playlists Used by Year",
                   xlabel = "Year",
                   ylabel = "Quantity")
# Out:
# <Axes: title={'center': 'Number of Playlists Used by Year'}, xlabel='Year', ylabel='Quantity'>

# %% [markdown]
# ## Create Niche Dataframes

# %% [markdown]
# #### Using 'playlists_df', make the friend_playlist_df which consists of all playlists in the 'friends_playlist' category

# %%
# Create a variable for the five playlist ids in the 'friends_playlist' 
# category

friend_playlist_ids = playlists_df.iloc[[5,9] , 0]
# friend_playlist_ids - Confirmed the desired playlists were selected

# %% [markdown]
# #### List all track names, ID's, and artist names in 'friend_playlist_ids'

# %%
# Loop through friend_playlist_ids using the get_all_tracks_from_playlist_function
# previously defined, to list all the track names, artist names, and track ids in 
# the five playlists in the 'friends_playlist' category

for playlist_id in friend_playlist_ids:
    tracks = get_all_tracks_from_playlist(playlist_id)
    
    for track in tracks:
        track_name = track["track"]["name"]
        artist_name = track["track"]["artists"][0]["name"]
        track_id = track["track"]["id"]
        print(f"Track: {track_name}, Artist: {artist_name}, Track ID: {track_id}")
# Out:
# Track: I Love It (& Lil Pump), Artist: Kanye West, Track ID: 4S8d14HvHb70ImctNgVzQQ
# Track: Stronger, Artist: Kanye West, Track ID: 6C7RJEIUDqKkJRZVWdkfkH
# Track: Walk It Talk It, Artist: Migos, Track ID: 6n4U3TlzUGhdSFbUUhTvLP
# Track: Stir Fry, Artist: Migos, Track ID: 2UVbBKQOdFAekPTRsnkzcf
# Track: Udd Gaye - Bacardi House Party Sessions, Artist: Ritviz, Track ID: 6wZJsut8fjiWiMPaccRAOX
# Track: Ambarsariya, Artist: Sona Mohapatra, Track ID: 4qRcjFkFqSpLBzcbLDt7HL
# Track: , Artist: , Track ID: 0ZHILXmUaVSLEOCWxPQ1ga
# Track: Dil Dhadakne Do, Artist: Joi Barua, Track ID: 46elU7IBKWf55D5sjHGqO7
# Track: , Artist: , Track ID: 4Zxh3OchJj7rOqa3B9ghT6
# Track: Sooraj Ki Baahon Mein, Artist: Dominique Cerejo, Track ID: 723xQva0yBF7M6K3nDAG8R
# Track: Jee Karda, Artist: Pritam, Track ID: 5yjKSIOtsenie9jgdSS5wr
# Track: Yaad Piya Ki Aane Lagi, Artist: Neha Kakkar, Track ID: 0TkquWzzuxcrwbCWlTrKYF
# Track: Udd Gaye - Bacardi House Party Sessions, Artist: Ritviz, Track ID: 6wZJsut8fjiWiMPaccRAOX
# Track: Dheeme Dheeme (From "Pati Patni Aur Woh"), Artist: Tony Kakkar, Track ID: 7ofWUKeNCUw1P64ArIwG9b
# Track: Lamberghini, Artist: The Doorbeen, Track ID: 45P9g6kUb7itdonjjGjDdS
# Track: Coca Cola (From "Luka Chuppi"), Artist: Tony Kakkar, Track ID: 352wEkChkiClswqwDoM0nj
# Track: Ghungroo (From "War"), Artist: Vishal-Shekhar, Track ID: 0WdbnNKO0Jt4BZACSDQh44
# Track: Lahore (From "Lahore"), Artist: Guru Randhawa, Track ID: 5VGINWbl9DKfr8a9QiCeOX
# Track: Nashe Si Chadh Gayi, Artist: Arijit Singh, Track ID: 2EKXTA9QxkW6XeQ2uEeIii
# Track: Proper Patola, Artist: Badshah, Track ID: 39ujbBjTwwqUFySaCYDMMT
# Track: La La La, Artist: Neha Kakkar, Track ID: 7oDykOViQGiV9M3enF7u4Y
# Track: , Artist: , Track ID: 6N6mJlsjYRV0yoMSPS5JiQ
# Track: , Artist: , Track ID: 3OZr3vo7SmYpn5XqeQEAOM

# %% [markdown]
# #### Get audio features for a track

# %%
# Use the audio_features function to get the full list of audio features of a
# song using the track id
# Create and review dataframe to confirm it is what I want

i_love_it_lil_pump = sp.audio_features("4S8d14HvHb70ImctNgVzQQ")
i_love_it_lil_pump_df = pd.DataFrame(i_love_it_lil_pump)
i_love_it_lil_pump_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.901   0.522    2    -8.304     1         0.33        0.0114
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0                 0     0.259    0.329  104.053  audio_features
#
#                        id                                   uri  \
# 0  4S8d14HvHb70ImctNgVzQQ  spotify:track:4S8d14HvHb70ImctNgVzQQ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4S8d14HvHb70...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4S8d...       127947
#
#    time_signature
# 0               4

# %% [markdown]
# ### Friends Playlists - Audio Features for Each Track

# %%
# Combine the logic of the previous 2 cells; using a loop to obtain track ids
# for all the tracks in friend_playlists_ids, and use the audio_features 
# function on all tracks in friend_playlists_ids

all_track_ids = []

for playlist_id in friend_playlist_ids:
    tracks = get_all_tracks_from_playlist(playlist_id)
    for track in tracks:
        track_id = track["track"]["id"]
        all_track_ids.append(track_id)

all_audio_features = []
for track_id in all_track_ids:
    audio_features = sp.audio_features(track_id)
    all_audio_features.extend(audio_features)

# Create a dataframe from all_audio_features

audio_features_df = pd.DataFrame(all_audio_features)
audio_features_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.901   0.522    2    -8.304     1       0.3300       0.01140
# 1           0.625   0.726   10    -7.731     0       0.1550       0.00728
# 2           0.907   0.633    2    -5.145     1       0.1840       0.08760
# 3           0.817   0.816    2    -5.402     1       0.2690       0.00263
# 4           0.904   0.518    2    -5.320     1       0.1830       0.03050
# ..            ...     ...  ...       ...   ...          ...           ...
# 136         0.800   0.779    4    -5.515     0       0.0553       0.11300
# 137         0.770   0.824    1    -6.491     0       0.0851       0.48500
# 138         0.774   0.781   10    -4.426     1       0.1040       0.34100
# 139         0.788   0.894    5    -2.661     0       0.1980       0.33900
# 140         0.614   0.842    6    -4.109     1       0.0745       0.00814
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.2590    0.329  104.053  audio_features
# 1            0.000000    0.3180    0.483  103.980  audio_features
# 2            0.000003    0.1060    0.395  145.914  audio_features
# 3            0.000000    0.1590    0.508  181.982  audio_features
# 4            0.000000    0.3250    0.188  137.996  audio_features
# ..                ...       ...      ...      ...             ...
# 136          0.000000    0.2060    0.266   96.948  audio_features
# 137          0.000000    0.3180    0.490  172.006  audio_features
# 138          0.000000    0.1110    0.469  100.017  audio_features
# 139          0.000253    0.0649    0.588   89.945  audio_features
# 140          0.000013    0.2120    0.915  156.051  audio_features
#
#                          id                                   uri  \
# 0    4S8d14HvHb70ImctNgVzQQ  spotify:track:4S8d14HvHb70ImctNgVzQQ
# 1    6C7RJEIUDqKkJRZVWdkfkH  spotify:track:6C7RJEIUDqKkJRZVWdkfkH
# 2    6n4U3TlzUGhdSFbUUhTvLP  spotify:track:6n4U3TlzUGhdSFbUUhTvLP
# 3    2UVbBKQOdFAekPTRsnkzcf  spotify:track:2UVbBKQOdFAekPTRsnkzcf
# 4    4wFjTWCunQFKtukqrNijEt  spotify:track:4wFjTWCunQFKtukqrNijEt
# ..                      ...                                   ...
# 136  2EKXTA9QxkW6XeQ2uEeIii  spotify:track:2EKXTA9QxkW6XeQ2uEeIii
# 137  39ujbBjTwwqUFySaCYDMMT  spotify:track:39ujbBjTwwqUFySaCYDMMT
# 138  7oDykOViQGiV9M3enF7u4Y  spotify:track:7oDykOViQGiV9M3enF7u4Y
# 139  6N6mJlsjYRV0yoMSPS5JiQ  spotify:track:6N6mJlsjYRV0yoMSPS5JiQ
# 140  3OZr3vo7SmYpn5XqeQEAOM  spotify:track:3OZr3vo7SmYpn5XqeQEAOM
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4S8d14HvHb70...
# 1    https://api.spotify.com/v1/tracks/6C7RJEIUDqKk...
# 2    https://api.spotify.com/v1/tracks/6n4U3TlzUGhd...
# 3    https://api.spotify.com/v1/tracks/2UVbBKQOdFAe...
# 4    https://api.spotify.com/v1/tracks/4wFjTWCunQFK...
# ..                                                 ...
# 136  https://api.spotify.com/v1/tracks/2EKXTA9QxkW6...
# 137  https://api.spotify.com/v1/tracks/39ujbBjTwwqU...
# 138  https://api.spotify.com/v1/tracks/7oDykOViQGiV...
# 139  https://api.spotify.com/v1/tracks/6N6mJlsjYRV0...
# 140  https://api.spotify.com/v1/tracks/3OZr3vo7SmYp...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4S8d...       127947
# 1    https://api.spotify.com/v1/audio-analysis/6C7R...       311867
# 2    https://api.spotify.com/v1/audio-analysis/6n4U...       276147
# 3    https://api.spotify.com/v1/audio-analysis/2UVb...       190288
# 4    https://api.spotify.com/v1/audio-analysis/4wFj...       303077
# ..                                                 ...          ...
# 136  https://api.spotify.com/v1/audio-analysis/2EKX...       238289
# 137  https://api.spotify.com/v1/audio-analysis/39uj...       178605
# 138  https://api.spotify.com/v1/audio-analysis/7oDy...       192000
# 139  https://api.spotify.com/v1/audio-analysis/6N6m...       196000
# 140  https://api.spotify.com/v1/audio-analysis/3OZr...       203207
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 136               4
# 137               4
# 138               4
# 139               4
# 140               4
#
# [141 rows x 18 columns]

# %%
# List column names to easily be able to drop unwanted columns
audio_features_df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
# Drop columns that are irrelevant to my analysis

audio_features_df.drop(columns = ['analysis_url', 'time_signature'],
                       inplace = True,
                       axis = 1)
audio_features_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.901   0.522    2    -8.304     1       0.3300       0.01140
# 1           0.625   0.726   10    -7.731     0       0.1550       0.00728
# 2           0.907   0.633    2    -5.145     1       0.1840       0.08760
# 3           0.817   0.816    2    -5.402     1       0.2690       0.00263
# 4           0.904   0.518    2    -5.320     1       0.1830       0.03050
# ..            ...     ...  ...       ...   ...          ...           ...
# 136         0.800   0.779    4    -5.515     0       0.0553       0.11300
# 137         0.770   0.824    1    -6.491     0       0.0851       0.48500
# 138         0.774   0.781   10    -4.426     1       0.1040       0.34100
# 139         0.788   0.894    5    -2.661     0       0.1980       0.33900
# 140         0.614   0.842    6    -4.109     1       0.0745       0.00814
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.2590    0.329  104.053  audio_features
# 1            0.000000    0.3180    0.483  103.980  audio_features
# 2            0.000003    0.1060    0.395  145.914  audio_features
# 3            0.000000    0.1590    0.508  181.982  audio_features
# 4            0.000000    0.3250    0.188  137.996  audio_features
# ..                ...       ...      ...      ...             ...
# 136          0.000000    0.2060    0.266   96.948  audio_features
# 137          0.000000    0.3180    0.490  172.006  audio_features
# 138          0.000000    0.1110    0.469  100.017  audio_features
# 139          0.000253    0.0649    0.588   89.945  audio_features
# 140          0.000013    0.2120    0.915  156.051  audio_features
#
#                          id                                   uri  \
# 0    4S8d14HvHb70ImctNgVzQQ  spotify:track:4S8d14HvHb70ImctNgVzQQ
# 1    6C7RJEIUDqKkJRZVWdkfkH  spotify:track:6C7RJEIUDqKkJRZVWdkfkH
# 2    6n4U3TlzUGhdSFbUUhTvLP  spotify:track:6n4U3TlzUGhdSFbUUhTvLP
# 3    2UVbBKQOdFAekPTRsnkzcf  spotify:track:2UVbBKQOdFAekPTRsnkzcf
# 4    4wFjTWCunQFKtukqrNijEt  spotify:track:4wFjTWCunQFKtukqrNijEt
# ..                      ...                                   ...
# 136  2EKXTA9QxkW6XeQ2uEeIii  spotify:track:2EKXTA9QxkW6XeQ2uEeIii
# 137  39ujbBjTwwqUFySaCYDMMT  spotify:track:39ujbBjTwwqUFySaCYDMMT
# 138  7oDykOViQGiV9M3enF7u4Y  spotify:track:7oDykOViQGiV9M3enF7u4Y
# 139  6N6mJlsjYRV0yoMSPS5JiQ  spotify:track:6N6mJlsjYRV0yoMSPS5JiQ
# 140  3OZr3vo7SmYpn5XqeQEAOM  spotify:track:3OZr3vo7SmYpn5XqeQEAOM
#
#                                             track_href  duration_ms
# 0    https://api.spotify.com/v1/tracks/4S8d14HvHb70...       127947
# 1    https://api.spotify.com/v1/tracks/6C7RJEIUDqKk...       311867
# 2    https://api.spotify.com/v1/tracks/6n4U3TlzUGhd...       276147
# 3    https://api.spotify.com/v1/tracks/2UVbBKQOdFAe...       190288
# 4    https://api.spotify.com/v1/tracks/4wFjTWCunQFK...       303077
# ..                                                 ...          ...
# 136  https://api.spotify.com/v1/tracks/2EKXTA9QxkW6...       238289
# 137  https://api.spotify.com/v1/tracks/39ujbBjTwwqU...       178605
# 138  https://api.spotify.com/v1/tracks/7oDykOViQGiV...       192000
# 139  https://api.spotify.com/v1/tracks/6N6mJlsjYRV0...       196000
# 140  https://api.spotify.com/v1/tracks/3OZr3vo7SmYp...       203207
#
# [141 rows x 16 columns]

# %% [markdown]
# ### Recently Played Songs

# %%
# Retrieve recently played songs by the user (me), and store the tracks in 
# 'recently_played__songs_df' dataframe

recent = sp.current_user_recently_played()
data = {"Track Name": [], "Artist(s)": [], "Album": [], "Played At": []}

while recent:
    for item in recent["items"]:
        data["Track Name"].append(item["track"]["name"])
        data["Artist(s)"].append(", ".join([artist["name"] for artist in item["track"]["artists"]]))
        data["Album"].append(item["track"]["album"]["name"])
        data["Played At"].append(item["played_at"])
    
    if recent["next"]:
        recent = sp.next(recent)
    else:
        recent = None

recently_played_songs_df = pd.DataFrame(data)
recently_played_songs_df
# Out:
#                                        Track Name  \
# 0                                Take You Dancing
# 1                                         YUM YUM
# 2                                          RATATA
# 3                   Talkin' Bout (feat. Saweetie)
# 4                                            Body
# 5                                       Womanizer
# 6                                        My Nigga
# 7                                     Jackie Chan
# 8                         F.Y.B.F - GOODIES REMIX
# 9                         F.Y.B.F - GOODIES REMIX
# 10                               Suttin Like That
# 11                        F.Y.B.F - GOODIES REMIX
# 12                        F.Y.B.F - GOODIES REMIX
# 13                                      L'ARMOIRE
# 14                              DANÇA NA CALÁBRIA
# 15                  Father Stretch My Hands Pt. 1
# 16                                        Anadrol
# 17                              DANÇA NA CALÁBRIA
# 18                            DERNIERE DANCE FUNK
# 19                                       COLUMBIA
# 20         MR. TAKE YA B*TCH (FEAT. CHRISEANROCK)
# 21                   HYFR (Hell Ya Fucking Right)
# 22                            DERNIERE DANCE FUNK
# 23                            DERNIERE DANCE FUNK
# 24                            Burn The House Down
# 25                            DERNIERE DANCE FUNK
# 26                              DANÇA NA CALÁBRIA
# 27                            DERNIERE DANCE FUNK
# 28                            DERNIERE DANCE FUNK
# 29                                  RITMO DO PEGA
# 30                            DERNIERE DANCE FUNK
# 31                                 Dernière danse
# 32                                         People
# 33        Medicated (feat. Chevy Woods & Juicy J)
# 34                  slide thru (feat. Jerry Good)
# 35                                       Amarillo
# 36                     Dies Irae feat. Black Prez
# 37                   I Love It (feat. Charli XCX)
# 38                                         RATATA
# 39                                        Bugatti
# 40                                        Anadrol
# 41                                  What You Know
# 42                                      La Modelo
# 17                       DANÇA NA CALÁBRIA  2024-03-17T21:21:43.304Z
# 18                     DERNIERE DANCE FUNK  2024-03-17T21:19:21.330Z
# 19            Fuck Your Expectations PT. 1  2024-03-17T21:05:56.257Z
# 20  MR. TAKE YA B*TCH (FEAT. CHRISEANROCK)  2024-03-17T21:02:50.134Z
# 21                      Take Care (Deluxe)  2024-03-17T21:01:04.279Z
# 22                     DERNIERE DANCE FUNK  2024-03-17T20:57:39.879Z
# 23                     DERNIERE DANCE FUNK  2024-03-17T20:55:44.962Z
# 24              The Click (Deluxe Edition)  2024-03-17T20:52:12.694Z
# 25                     DERNIERE DANCE FUNK  2024-03-17T20:48:34.243Z
# 26                       DANÇA NA CALÁBRIA  2024-03-17T20:43:37.172Z
# 27                     DERNIERE DANCE FUNK  2024-03-17T20:42:06.232Z
# 28                     DERNIERE DANCE FUNK  2024-03-17T20:39:48.416Z
# 29                           RITMO DO PEGA  2024-03-17T20:38:14.828Z
# 30                     DERNIERE DANCE FUNK  2024-03-17T20:36:48.567Z
# 31                              Mini World  2024-03-17T20:05:08.124Z
# 32                                  People  2024-03-17T20:00:20.282Z
# 33                     O.N.I.F.C. (Deluxe)  2024-03-17T19:57:18.258Z
# 34                                    help  2024-03-17T19:50:52.302Z
# 35                                 Colores  2024-03-17T19:47:50.370Z
# 36                                 Requiem  2024-03-17T19:45:15.194Z
# 37                    THIS IS... ICONA POP  2024-03-17T19:39:49.165Z
# 38                          Quest For Fire  2024-03-17T19:37:14.274Z
# 39          Trials & Tribulations (Deluxe)  2024-03-17T19:34:51.285Z
# 40                                 Anadrol  2024-03-17T19:30:25.180Z
# 41                         Tourist History  2024-03-17T19:21:42.164Z
# 42                                    Aura  2024-03-17T19:16:42.119Z
# 43                             Look At Me!  2024-03-17T19:12:25.180Z
# 44                             LUV (Remix)  2024-03-17T19:10:21.277Z
# 45                  Greatest Hits Volume 2  2024-03-17T19:07:37.171Z
# 46                      MAÑANA SERÁ BONITO  2024-03-17T19:01:26.158Z
# 47                           Playboi Carti  2024-03-17T18:58:10.186Z
# 48                              Artist 2.0  2024-03-17T18:55:11.185Z
# 49                                 Requiem  2024-03-17T18:52:10.383Z

# %% [markdown]
# #### Plot a graph showing the hours of the day of my recently played songs

# %%
# Convert the 'Played At' column of recently_played_songs_df to datetime format

recently_played_songs_df['Played At'] = pd.to_datetime(recently_played_songs_df['Played At'])

# Isolate the hour that each song was played

recently_played_songs_df["Hour"] = recently_played_songs_df['Played At'].dt.hour

# Quantify the number of songs played each hour, and groupby the 'Hour'

hourly_counts = recently_played_songs_df.groupby('Hour').size()

# %%
# Plot the graph

hourly_counts.plot(kind = "bar",
                    title = "Number of Songs Played by Hour of the Day",
                   xlabel = "Hour of the Day",
                   ylabel = "Number of Songs Played",
                   color = "purple")
# Out:
# <Axes: title={'center': 'Number of Songs Played by Hour of the Day'}, xlabel='Hour of the Day', ylabel='Number of Songs Played'>

# %% [markdown]
# ### From the graph, we can conclude I usually listen to music at night rather than during the day. Only two tracks were listened to in the morning, and the rest were listened from 4pm and later. I am usually up late so these results are not surprising to me 😆🌛
